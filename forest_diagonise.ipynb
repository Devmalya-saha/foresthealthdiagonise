# %%
import os
import torch
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
# Paths
image_dir = r'Data_Set_Larch_Casebearer/Imagedata'
augmented_dir = r'Data_Set_Larch_Casebearer/Augmented_Images'

# Create directory to save augmented images if it doesn't exist
if not os.path.exists(augmented_dir):
    os.makedirs(augmented_dir)

# %%
# Define ImageNet normalization (mean and std)
imagenet_normalization = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

# Define preprocessing transformations: resize, to tensor, normalization
preprocess = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.ToTensor(),          
    imagenet_normalization,         
])

# Define augmentation transformations
augmentations = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),   
    transforms.RandomRotation(20),           
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1)  
])

# Function to unnormalize the image for display or saving
def unnormalize(tensor):
    mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    return tensor * std + mean

# Convert tensor to NumPy array for display or saving
def tensor_to_numpy(tensor):
    tensor = tensor.permute(1, 2, 0)  # Change dimensions from [C, H, W] to [H, W, C]
    tensor = tensor.detach().numpy()  # Convert to NumPy array
    tensor = np.clip(tensor, 0, 1)    # Clip the values between 0 and 1 for proper display
    return tensor

# Iterate over all images in the dataset
for img_name in os.listdir(image_dir):
    if img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
        # Load the image
        img_path = os.path.join(image_dir, img_name)
        image = Image.open(img_path).convert('RGB')
        
        # Apply preprocessing and augmentation
        image_tensor = preprocess(image)
        augmented_image_tensor = augmentations(image_tensor)
        
        # Unnormalize the augmented image for visualization or saving
        unnormalized_augmented_image = unnormalize(augmented_image_tensor)
        
        # Convert to NumPy array for displaying or saving
        augmented_image_np = tensor_to_numpy(unnormalized_augmented_image)
        
        # Convert to PIL Image and save the augmented image
        augmented_image_pil = Image.fromarray((augmented_image_np * 255).astype(np.uint8))
        augmented_img_name = f"augmented_{img_name}"
        augmented_img_path = os.path.join(augmented_dir, augmented_img_name)
        augmented_image_pil.save(augmented_img_path)
print("Image augmentation complete!")

# %%
plt.figure(figsize=(5, 5))
        plt.imshow(augmented_image_np)
        plt.title(f'Augmented Image: {img_name}')
        plt.axis('off')  # Hide axis for better display
        plt.show()
# Out:
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_34688\2917902397.py", line 2
#     plt.imshow(augmented_image_np)
#     ^
# IndentationError: unexpected indent

# %%
import xml.etree.ElementTree as ET
import os

# Function to parse the annotation file and count tree categories
def count_tree_categories(annotation_file):
    # Initialize counts
    counts = {
        'Healthy (H)': 0,
        'Light Damage (LD)': 0,
        'High Damage (HD)': 0,
        'Other': 0,
        'Total tree':0,
        'Health Score':0,
        'Damaged or Stressed':0,
        'Label':""
    }
    
    # Parse the XML file
    tree = ET.parse(annotation_file)
    root = tree.getroot()
    
    # Iterate through the objects in the annotation
    
    for obj in root.iter('object'):
        treet= obj.find('tree')
        if treet is not None:
            tree_type=treet.text
        else:
            tree_type=None
        d= obj.find('damage')
        if d is not None:
            damage_status=d.text
        else:
            damage_status=None
        
        # Update counts based on damage status
        if damage_status == 'H':
            counts['Healthy (H)'] += 1
        elif damage_status == 'LD':
            counts['Light Damage (LD)'] += 1
        elif damage_status == 'HD':
            counts['High Damage (HD)'] += 1
        elif damage_status== 'other':
            counts['Other'] += 1
        if tree_type:
            counts['Total tree']+=1
    if counts['Total tree']:        
         counts['Health Score']=(counts['Healthy (H)']/counts['Total tree'])*100
         counts['Damaged or Stressed']=((counts['Light Damage (LD)']+counts['High Damage (HD)'])/counts['Total tree'])*100
    if counts['Health Score']>=60:
        counts['Label']='Healthy'
    else:
        counts['Label']='Damaged/Stressed'
        
    return counts

total_counts = {
    'Healthy (H)': 0,
    'Light Damage (LD)': 0,
    'High Damage (HD)': 0,
    'Other': 0
}

# Example usage
image_path = r"C:\Users\User\Desktop\RESEARCH\Data_Set_Larch_Casebearer\Imagedata"
annotation_path = r"C:\Users\User\Desktop\RESEARCH\Data_Set_Larch_Casebearer\Annotations"

# Iterate through images and their corresponding annotations
image_filenames = os.listdir(image_path)

for img_name in image_filenames:
    if img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
        # Construct the corresponding annotation filename
        annotation_file = img_name.replace('.JPG', '.xml').replace('.jpeg', '.xml').replace('.png', '.xml')
        annotation_file_path = os.path.join(annotation_path, annotation_file)
        
        # Count the categories
        if os.path.exists(annotation_file_path):
            counts = count_tree_categories(annotation_file_path)
            print(f"Counts for {img_name}: {counts}")
            total_counts['Healthy (H)'] += counts['Healthy (H)']
            total_counts['Light Damage (LD)'] += counts['Light Damage (LD)']
            total_counts['High Damage (HD)'] += counts['High Damage (HD)']
            total_counts['Other'] += counts['Other']
        else:
            print(f"Annotation file not found for {img_name}: {annotation_file_path}")
# Print the total counts
print("Total counts across the dataset:")
print(f"Healthy (H): {total_counts['Healthy (H)']}")
print(f"Light Damage (LD): {total_counts['Light Damage (LD)']}")
print(f"High Damage (HD): {total_counts['High Damage (HD)']}")
print(f"Other: {total_counts['Other']}")
# Out:
# Counts for B01_0004.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 31, 'High Damage (HD)': 22, 'Other': 4, 'Total tree': 57, 'Health Score': 0.0, 'Damaged or Stressed': 92.98245614035088, 'Label': 'Damaged/Stressed'}
# Counts for B01_0005.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 23, 'High Damage (HD)': 9, 'Other': 12, 'Total tree': 44, 'Health Score': 0.0, 'Damaged or Stressed': 72.72727272727273, 'Label': 'Damaged/Stressed'}
# Counts for B01_0006.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 31, 'High Damage (HD)': 2, 'Other': 10, 'Total tree': 44, 'Health Score': 2.272727272727273, 'Damaged or Stressed': 75.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0007.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 8, 'High Damage (HD)': 6, 'Other': 10, 'Total tree': 24, 'Health Score': 0.0, 'Damaged or Stressed': 58.333333333333336, 'Label': 'Damaged/Stressed'}
# Counts for B01_0012.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 3, 'High Damage (HD)': 9, 'Other': 35, 'Total tree': 47, 'Health Score': 0.0, 'Damaged or Stressed': 25.53191489361702, 'Label': 'Damaged/Stressed'}
# Counts for B01_0013.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 13, 'High Damage (HD)': 34, 'Other': 9, 'Total tree': 56, 'Health Score': 0.0, 'Damaged or Stressed': 83.92857142857143, 'Label': 'Damaged/Stressed'}
# Counts for B01_0014.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 31, 'High Damage (HD)': 15, 'Other': 15, 'Total tree': 61, 'Health Score': 0.0, 'Damaged or Stressed': 75.40983606557377, 'Label': 'Damaged/Stressed'}
# Counts for B01_0015.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 30, 'High Damage (HD)': 4, 'Other': 23, 'Total tree': 57, 'Health Score': 0.0, 'Damaged or Stressed': 59.64912280701754, 'Label': 'Damaged/Stressed'}
# Counts for B01_0016.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 40, 'High Damage (HD)': 9, 'Other': 19, 'Total tree': 68, 'Health Score': 0.0, 'Damaged or Stressed': 72.05882352941177, 'Label': 'Damaged/Stressed'}
# Counts for B01_0017.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 19, 'High Damage (HD)': 20, 'Other': 28, 'Total tree': 67, 'Health Score': 0.0, 'Damaged or Stressed': 58.2089552238806, 'Label': 'Damaged/Stressed'}
# Counts for B01_0018.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 25, 'High Damage (HD)': 8, 'Other': 21, 'Total tree': 54, 'Health Score': 0.0, 'Damaged or Stressed': 61.111111111111114, 'Label': 'Damaged/Stressed'}
# Counts for B01_0019.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 41, 'High Damage (HD)': 2, 'Other': 14, 'Total tree': 58, 'Health Score': 1.7241379310344827, 'Damaged or Stressed': 74.13793103448276, 'Label': 'Damaged/Stressed'}
# Counts for B01_0020.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 57, 'High Damage (HD)': 1, 'Other': 10, 'Total tree': 70, 'Health Score': 2.857142857142857, 'Damaged or Stressed': 82.85714285714286, 'Label': 'Damaged/Stressed'}
# Counts for B01_0021.JPG: {'Healthy (H)': 3, 'Light Damage (LD)': 53, 'High Damage (HD)': 3, 'Other': 6, 'Total tree': 65, 'Health Score': 4.615384615384616, 'Damaged or Stressed': 86.15384615384616, 'Label': 'Damaged/Stressed'}
# Counts for B01_0022.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 16, 'High Damage (HD)': 8, 'Other': 5, 'Total tree': 29, 'Health Score': 0.0, 'Damaged or Stressed': 82.75862068965517, 'Label': 'Damaged/Stressed'}
# Counts for B01_0024.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 1, 'Other': 18, 'Total tree': 19, 'Health Score': 0.0, 'Damaged or Stressed': 5.263157894736842, 'Label': 'Damaged/Stressed'}
# Counts for B01_0025.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 20, 'High Damage (HD)': 15, 'Other': 10, 'Total tree': 45, 'Health Score': 0.0, 'Damaged or Stressed': 77.77777777777779, 'Label': 'Damaged/Stressed'}
# Counts for B01_0026.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 44, 'High Damage (HD)': 4, 'Other': 5, 'Total tree': 53, 'Health Score': 0.0, 'Damaged or Stressed': 90.56603773584906, 'Label': 'Damaged/Stressed'}
# Counts for B01_0027.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 35, 'High Damage (HD)': 2, 'Other': 19, 'Total tree': 56, 'Health Score': 0.0, 'Damaged or Stressed': 66.07142857142857, 'Label': 'Damaged/Stressed'}
# Counts for B01_0028.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 43, 'High Damage (HD)': 2, 'Other': 18, 'Total tree': 63, 'Health Score': 0.0, 'Damaged or Stressed': 71.42857142857143, 'Label': 'Damaged/Stressed'}
# Counts for B01_0029.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 23, 'High Damage (HD)': 7, 'Other': 40, 'Total tree': 72, 'Health Score': 2.7777777777777777, 'Damaged or Stressed': 41.66666666666667, 'Label': 'Damaged/Stressed'}
# Counts for B01_0030.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 12, 'High Damage (HD)': 13, 'Other': 33, 'Total tree': 58, 'Health Score': 0.0, 'Damaged or Stressed': 43.103448275862064, 'Label': 'Damaged/Stressed'}
# Counts for B01_0031.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 11, 'High Damage (HD)': 17, 'Other': 31, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 47.45762711864407, 'Label': 'Damaged/Stressed'}
# Counts for B01_0032.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 35, 'High Damage (HD)': 12, 'Other': 6, 'Total tree': 53, 'Health Score': 0.0, 'Damaged or Stressed': 88.67924528301887, 'Label': 'Damaged/Stressed'}
# Counts for B01_0033.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 27, 'High Damage (HD)': 16, 'Other': 4, 'Total tree': 47, 'Health Score': 0.0, 'Damaged or Stressed': 91.48936170212765, 'Label': 'Damaged/Stressed'}
# Counts for B01_0034.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 24, 'High Damage (HD)': 28, 'Other': 5, 'Total tree': 57, 'Health Score': 0.0, 'Damaged or Stressed': 91.22807017543859, 'Label': 'Damaged/Stressed'}
# Counts for B01_0035.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 25, 'High Damage (HD)': 14, 'Other': 6, 'Total tree': 45, 'Health Score': 0.0, 'Damaged or Stressed': 86.66666666666667, 'Label': 'Damaged/Stressed'}
# Counts for B01_0036.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 17, 'High Damage (HD)': 20, 'Other': 3, 'Total tree': 40, 'Health Score': 0.0, 'Damaged or Stressed': 92.5, 'Label': 'Damaged/Stressed'}
# Counts for B01_0037.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 34, 'High Damage (HD)': 12, 'Other': 18, 'Total tree': 64, 'Health Score': 0.0, 'Damaged or Stressed': 71.875, 'Label': 'Damaged/Stressed'}
# Counts for B01_0038.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 28, 'High Damage (HD)': 12, 'Other': 13, 'Total tree': 53, 'Health Score': 0.0, 'Damaged or Stressed': 75.47169811320755, 'Label': 'Damaged/Stressed'}
# Counts for B01_0039.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 49, 'High Damage (HD)': 10, 'Other': 14, 'Total tree': 73, 'Health Score': 0.0, 'Damaged or Stressed': 80.82191780821918, 'Label': 'Damaged/Stressed'}
# Counts for B01_0040.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 43, 'High Damage (HD)': 6, 'Other': 26, 'Total tree': 76, 'Health Score': 1.3157894736842104, 'Damaged or Stressed': 64.47368421052632, 'Label': 'Damaged/Stressed'}
# Counts for B01_0041.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 32, 'High Damage (HD)': 10, 'Other': 28, 'Total tree': 70, 'Health Score': 0.0, 'Damaged or Stressed': 60.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0042.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 50, 'High Damage (HD)': 6, 'Other': 18, 'Total tree': 74, 'Health Score': 0.0, 'Damaged or Stressed': 75.67567567567568, 'Label': 'Damaged/Stressed'}
# Counts for B01_0043.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 59, 'High Damage (HD)': 2, 'Other': 12, 'Total tree': 73, 'Health Score': 0.0, 'Damaged or Stressed': 83.56164383561644, 'Label': 'Damaged/Stressed'}
# Counts for B01_0044.JPG: {'Healthy (H)': 5, 'Light Damage (LD)': 43, 'High Damage (HD)': 1, 'Other': 4, 'Total tree': 53, 'Health Score': 9.433962264150944, 'Damaged or Stressed': 83.01886792452831, 'Label': 'Damaged/Stressed'}
# Counts for B01_0045.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 32, 'High Damage (HD)': 9, 'Other': 7, 'Total tree': 49, 'Health Score': 2.0408163265306123, 'Damaged or Stressed': 83.6734693877551, 'Label': 'Damaged/Stressed'}
# Counts for B01_0046.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 8, 'High Damage (HD)': 2, 'Other': 16, 'Total tree': 26, 'Health Score': 0.0, 'Damaged or Stressed': 38.46153846153847, 'Label': 'Damaged/Stressed'}
# Counts for B01_0047.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 8, 'High Damage (HD)': 0, 'Other': 22, 'Total tree': 30, 'Health Score': 0.0, 'Damaged or Stressed': 26.666666666666668, 'Label': 'Damaged/Stressed'}
# Annotation file not found for B01_0048.JPG: C:\Users\User\Desktop\RESEARCH\Data_Set_Larch_Casebearer\Annotations\B01_0048.xml
# Counts for B01_0049.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 3, 'High Damage (HD)': 4, 'Other': 21, 'Total tree': 28, 'Health Score': 0.0, 'Damaged or Stressed': 25.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0050.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 5, 'High Damage (HD)': 1, 'Other': 16, 'Total tree': 22, 'Health Score': 0.0, 'Damaged or Stressed': 27.27272727272727, 'Label': 'Damaged/Stressed'}
# Counts for B01_0051.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 8, 'High Damage (HD)': 3, 'Other': 13, 'Total tree': 24, 'Health Score': 0.0, 'Damaged or Stressed': 45.83333333333333, 'Label': 'Damaged/Stressed'}
# Counts for B01_0052.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 39, 'High Damage (HD)': 6, 'Other': 8, 'Total tree': 53, 'Health Score': 0.0, 'Damaged or Stressed': 84.90566037735849, 'Label': 'Damaged/Stressed'}
# Counts for B01_0053.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 61, 'High Damage (HD)': 2, 'Other': 7, 'Total tree': 72, 'Health Score': 2.7777777777777777, 'Damaged or Stressed': 87.5, 'Label': 'Damaged/Stressed'}
# Counts for B01_0054.JPG: {'Healthy (H)': 5, 'Light Damage (LD)': 49, 'High Damage (HD)': 0, 'Other': 11, 'Total tree': 65, 'Health Score': 7.6923076923076925, 'Damaged or Stressed': 75.38461538461539, 'Label': 'Damaged/Stressed'}
# Counts for B01_0055.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 46, 'High Damage (HD)': 3, 'Other': 11, 'Total tree': 62, 'Health Score': 3.225806451612903, 'Damaged or Stressed': 79.03225806451613, 'Label': 'Damaged/Stressed'}
# Counts for B01_0056.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 42, 'High Damage (HD)': 8, 'Other': 17, 'Total tree': 69, 'Health Score': 2.898550724637681, 'Damaged or Stressed': 72.46376811594203, 'Label': 'Damaged/Stressed'}
# Counts for B01_0057.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 33, 'High Damage (HD)': 9, 'Other': 19, 'Total tree': 61, 'Health Score': 0.0, 'Damaged or Stressed': 68.85245901639344, 'Label': 'Damaged/Stressed'}
# Counts for B01_0058.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 20, 'High Damage (HD)': 15, 'Other': 15, 'Total tree': 51, 'Health Score': 1.9607843137254901, 'Damaged or Stressed': 68.62745098039215, 'Label': 'Damaged/Stressed'}
# Counts for B01_0059.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 20, 'High Damage (HD)': 26, 'Other': 11, 'Total tree': 59, 'Health Score': 3.389830508474576, 'Damaged or Stressed': 77.96610169491525, 'Label': 'Damaged/Stressed'}
# Counts for B01_0060.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 41, 'High Damage (HD)': 27, 'Other': 2, 'Total tree': 70, 'Health Score': 0.0, 'Damaged or Stressed': 97.14285714285714, 'Label': 'Damaged/Stressed'}
# Counts for B01_0061.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 32, 'High Damage (HD)': 9, 'Other': 11, 'Total tree': 52, 'Health Score': 0.0, 'Damaged or Stressed': 78.84615384615384, 'Label': 'Damaged/Stressed'}
# Counts for B01_0062.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 1, 'Other': 12, 'Total tree': 13, 'Health Score': 0.0, 'Damaged or Stressed': 7.6923076923076925, 'Label': 'Damaged/Stressed'}
# Counts for B01_0063.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 19, 'High Damage (HD)': 15, 'Other': 13, 'Total tree': 49, 'Health Score': 4.081632653061225, 'Damaged or Stressed': 69.38775510204081, 'Label': 'Damaged/Stressed'}
# Counts for B01_0064.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 48, 'High Damage (HD)': 0, 'Other': 13, 'Total tree': 63, 'Health Score': 3.1746031746031744, 'Damaged or Stressed': 76.19047619047619, 'Label': 'Damaged/Stressed'}
# Counts for B01_0065.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 61, 'High Damage (HD)': 8, 'Other': 1, 'Total tree': 70, 'Health Score': 0.0, 'Damaged or Stressed': 98.57142857142858, 'Label': 'Damaged/Stressed'}
# Counts for B01_0066.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 46, 'High Damage (HD)': 10, 'Other': 8, 'Total tree': 65, 'Health Score': 1.5384615384615385, 'Damaged or Stressed': 86.15384615384616, 'Label': 'Damaged/Stressed'}
# Counts for B01_0067.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 41, 'High Damage (HD)': 2, 'Other': 15, 'Total tree': 59, 'Health Score': 1.694915254237288, 'Damaged or Stressed': 72.88135593220339, 'Label': 'Damaged/Stressed'}
# Counts for B01_0068.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 44, 'High Damage (HD)': 2, 'Other': 15, 'Total tree': 63, 'Health Score': 3.1746031746031744, 'Damaged or Stressed': 73.01587301587301, 'Label': 'Damaged/Stressed'}
# Counts for B01_0069.JPG: {'Healthy (H)': 17, 'Light Damage (LD)': 38, 'High Damage (HD)': 1, 'Other': 10, 'Total tree': 66, 'Health Score': 25.757575757575758, 'Damaged or Stressed': 59.09090909090909, 'Label': 'Damaged/Stressed'}
# Counts for B01_0070.JPG: {'Healthy (H)': 20, 'Light Damage (LD)': 25, 'High Damage (HD)': 0, 'Other': 5, 'Total tree': 50, 'Health Score': 40.0, 'Damaged or Stressed': 50.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0071.JPG: {'Healthy (H)': 5, 'Light Damage (LD)': 26, 'High Damage (HD)': 1, 'Other': 4, 'Total tree': 36, 'Health Score': 13.88888888888889, 'Damaged or Stressed': 75.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0072.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 23, 'High Damage (HD)': 3, 'Other': 5, 'Total tree': 31, 'Health Score': 0.0, 'Damaged or Stressed': 83.87096774193549, 'Label': 'Damaged/Stressed'}
# Counts for B01_0073.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 42, 'High Damage (HD)': 2, 'Other': 8, 'Total tree': 52, 'Health Score': 0.0, 'Damaged or Stressed': 84.61538461538461, 'Label': 'Damaged/Stressed'}
# Counts for B01_0074.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 57, 'High Damage (HD)': 4, 'Other': 10, 'Total tree': 71, 'Health Score': 0.0, 'Damaged or Stressed': 85.91549295774648, 'Label': 'Damaged/Stressed'}
# Counts for B01_0075.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 51, 'High Damage (HD)': 12, 'Other': 17, 'Total tree': 80, 'Health Score': 0.0, 'Damaged or Stressed': 78.75, 'Label': 'Damaged/Stressed'}
# Counts for B01_0076.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 16, 'High Damage (HD)': 7, 'Other': 36, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 38.983050847457626, 'Label': 'Damaged/Stressed'}
# Counts for B01_0077.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 13, 'High Damage (HD)': 6, 'Other': 52, 'Total tree': 71, 'Health Score': 0.0, 'Damaged or Stressed': 26.76056338028169, 'Label': 'Damaged/Stressed'}
# Counts for B01_0078.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 11, 'High Damage (HD)': 3, 'Other': 35, 'Total tree': 49, 'Health Score': 0.0, 'Damaged or Stressed': 28.57142857142857, 'Label': 'Damaged/Stressed'}
# Counts for B01_0079.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 46, 'High Damage (HD)': 13, 'Other': 14, 'Total tree': 73, 'Health Score': 0.0, 'Damaged or Stressed': 80.82191780821918, 'Label': 'Damaged/Stressed'}
# Counts for B01_0080.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 67, 'High Damage (HD)': 16, 'Other': 7, 'Total tree': 90, 'Health Score': 0.0, 'Damaged or Stressed': 92.22222222222223, 'Label': 'Damaged/Stressed'}
# Counts for B01_0081.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 69, 'High Damage (HD)': 10, 'Other': 8, 'Total tree': 87, 'Health Score': 0.0, 'Damaged or Stressed': 90.80459770114942, 'Label': 'Damaged/Stressed'}
# Counts for B01_0082.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 59, 'High Damage (HD)': 9, 'Other': 3, 'Total tree': 71, 'Health Score': 0.0, 'Damaged or Stressed': 95.77464788732394, 'Label': 'Damaged/Stressed'}
# Counts for B01_0083.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 56, 'High Damage (HD)': 2, 'Other': 4, 'Total tree': 62, 'Health Score': 0.0, 'Damaged or Stressed': 93.54838709677419, 'Label': 'Damaged/Stressed'}
# Counts for B01_0084.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 50, 'High Damage (HD)': 2, 'Other': 7, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 88.13559322033898, 'Label': 'Damaged/Stressed'}
# Counts for B01_0085.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 20, 'High Damage (HD)': 6, 'Other': 11, 'Total tree': 37, 'Health Score': 0.0, 'Damaged or Stressed': 70.27027027027027, 'Label': 'Damaged/Stressed'}
# Counts for B01_0086.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 18, 'High Damage (HD)': 1, 'Other': 14, 'Total tree': 33, 'Health Score': 0.0, 'Damaged or Stressed': 57.57575757575758, 'Label': 'Damaged/Stressed'}
# Counts for B01_0087.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 33, 'High Damage (HD)': 2, 'Other': 3, 'Total tree': 39, 'Health Score': 2.564102564102564, 'Damaged or Stressed': 89.74358974358975, 'Label': 'Damaged/Stressed'}
# Counts for B01_0088.JPG: {'Healthy (H)': 6, 'Light Damage (LD)': 26, 'High Damage (HD)': 1, 'Other': 7, 'Total tree': 40, 'Health Score': 15.0, 'Damaged or Stressed': 67.5, 'Label': 'Damaged/Stressed'}
# Counts for B01_0089.JPG: {'Healthy (H)': 11, 'Light Damage (LD)': 28, 'High Damage (HD)': 1, 'Other': 3, 'Total tree': 43, 'Health Score': 25.581395348837212, 'Damaged or Stressed': 67.44186046511628, 'Label': 'Damaged/Stressed'}
# Counts for B01_0090.JPG: {'Healthy (H)': 12, 'Light Damage (LD)': 63, 'High Damage (HD)': 1, 'Other': 2, 'Total tree': 78, 'Health Score': 15.384615384615385, 'Damaged or Stressed': 82.05128205128204, 'Label': 'Damaged/Stressed'}
# Counts for B01_0091.JPG: {'Healthy (H)': 3, 'Light Damage (LD)': 43, 'High Damage (HD)': 26, 'Other': 7, 'Total tree': 79, 'Health Score': 3.79746835443038, 'Damaged or Stressed': 87.34177215189874, 'Label': 'Damaged/Stressed'}
# Counts for B01_0092.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 38, 'High Damage (HD)': 26, 'Other': 5, 'Total tree': 70, 'Health Score': 1.4285714285714286, 'Damaged or Stressed': 91.42857142857143, 'Label': 'Damaged/Stressed'}
# Counts for B01_0093.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 26, 'High Damage (HD)': 12, 'Other': 20, 'Total tree': 58, 'Health Score': 0.0, 'Damaged or Stressed': 65.51724137931035, 'Label': 'Damaged/Stressed'}
# Counts for B01_0094.JPG: {'Healthy (H)': 8, 'Light Damage (LD)': 77, 'High Damage (HD)': 7, 'Other': 6, 'Total tree': 98, 'Health Score': 8.16326530612245, 'Damaged or Stressed': 85.71428571428571, 'Label': 'Damaged/Stressed'}
# Counts for B01_0095.JPG: {'Healthy (H)': 9, 'Light Damage (LD)': 80, 'High Damage (HD)': 1, 'Other': 6, 'Total tree': 96, 'Health Score': 9.375, 'Damaged or Stressed': 84.375, 'Label': 'Damaged/Stressed'}
# Counts for B01_0096.JPG: {'Healthy (H)': 3, 'Light Damage (LD)': 68, 'High Damage (HD)': 0, 'Other': 4, 'Total tree': 75, 'Health Score': 4.0, 'Damaged or Stressed': 90.66666666666666, 'Label': 'Damaged/Stressed'}
# Counts for B01_0097.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 55, 'High Damage (HD)': 0, 'Other': 5, 'Total tree': 60, 'Health Score': 0.0, 'Damaged or Stressed': 91.66666666666666, 'Label': 'Damaged/Stressed'}
# Counts for B01_0098.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 54, 'High Damage (HD)': 2, 'Other': 4, 'Total tree': 60, 'Health Score': 0.0, 'Damaged or Stressed': 93.33333333333333, 'Label': 'Damaged/Stressed'}
# Counts for B01_0099.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 15, 'High Damage (HD)': 2, 'Other': 23, 'Total tree': 40, 'Health Score': 0.0, 'Damaged or Stressed': 42.5, 'Label': 'Damaged/Stressed'}
# Counts for B01_0100.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 41, 'High Damage (HD)': 2, 'Other': 9, 'Total tree': 53, 'Health Score': 1.8867924528301887, 'Damaged or Stressed': 81.13207547169812, 'Label': 'Damaged/Stressed'}
# Counts for B01_0101.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 49, 'High Damage (HD)': 3, 'Other': 7, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 88.13559322033898, 'Label': 'Damaged/Stressed'}
# Counts for B01_0102.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 69, 'High Damage (HD)': 1, 'Other': 4, 'Total tree': 74, 'Health Score': 0.0, 'Damaged or Stressed': 94.5945945945946, 'Label': 'Damaged/Stressed'}
# Counts for B01_0103.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 66, 'High Damage (HD)': 13, 'Other': 0, 'Total tree': 79, 'Health Score': 0.0, 'Damaged or Stressed': 100.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0104.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 56, 'High Damage (HD)': 35, 'Other': 4, 'Total tree': 95, 'Health Score': 0.0, 'Damaged or Stressed': 95.78947368421052, 'Label': 'Damaged/Stressed'}
# Counts for B01_0105.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 36, 'High Damage (HD)': 19, 'Other': 9, 'Total tree': 64, 'Health Score': 0.0, 'Damaged or Stressed': 85.9375, 'Label': 'Damaged/Stressed'}
# Counts for B01_0106.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 5, 'High Damage (HD)': 1, 'Other': 41, 'Total tree': 47, 'Health Score': 0.0, 'Damaged or Stressed': 12.76595744680851, 'Label': 'Damaged/Stressed'}
# Counts for B01_0107.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 4, 'High Damage (HD)': 0, 'Other': 45, 'Total tree': 49, 'Health Score': 0.0, 'Damaged or Stressed': 8.16326530612245, 'Label': 'Damaged/Stressed'}
# Counts for B01_0108.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 3, 'High Damage (HD)': 0, 'Other': 45, 'Total tree': 48, 'Health Score': 0.0, 'Damaged or Stressed': 6.25, 'Label': 'Damaged/Stressed'}
# Counts for B01_0109.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 34, 'High Damage (HD)': 5, 'Other': 22, 'Total tree': 61, 'Health Score': 0.0, 'Damaged or Stressed': 63.934426229508205, 'Label': 'Damaged/Stressed'}
# Counts for B01_0110.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 73, 'High Damage (HD)': 19, 'Other': 6, 'Total tree': 98, 'Health Score': 0.0, 'Damaged or Stressed': 93.87755102040816, 'Label': 'Damaged/Stressed'}
# Counts for B01_0111.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 78, 'High Damage (HD)': 2, 'Other': 3, 'Total tree': 83, 'Health Score': 0.0, 'Damaged or Stressed': 96.3855421686747, 'Label': 'Damaged/Stressed'}
# Counts for B01_0112.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 59, 'High Damage (HD)': 3, 'Other': 5, 'Total tree': 67, 'Health Score': 0.0, 'Damaged or Stressed': 92.53731343283582, 'Label': 'Damaged/Stressed'}
# Counts for B01_0113.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 55, 'High Damage (HD)': 6, 'Other': 2, 'Total tree': 63, 'Health Score': 0.0, 'Damaged or Stressed': 96.82539682539682, 'Label': 'Damaged/Stressed'}
# Counts for B01_0114.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 20, 'High Damage (HD)': 0, 'Other': 7, 'Total tree': 27, 'Health Score': 0.0, 'Damaged or Stressed': 74.07407407407408, 'Label': 'Damaged/Stressed'}
# Counts for B01_0115.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 34, 'High Damage (HD)': 5, 'Other': 13, 'Total tree': 53, 'Health Score': 1.8867924528301887, 'Damaged or Stressed': 73.58490566037736, 'Label': 'Damaged/Stressed'}
# Counts for B01_0116.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 55, 'High Damage (HD)': 1, 'Other': 6, 'Total tree': 62, 'Health Score': 0.0, 'Damaged or Stressed': 90.32258064516128, 'Label': 'Damaged/Stressed'}
# Counts for B01_0117.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 71, 'High Damage (HD)': 1, 'Other': 3, 'Total tree': 75, 'Health Score': 0.0, 'Damaged or Stressed': 96.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0118.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 77, 'High Damage (HD)': 0, 'Other': 9, 'Total tree': 87, 'Health Score': 1.1494252873563218, 'Damaged or Stressed': 88.50574712643679, 'Label': 'Damaged/Stressed'}
# Counts for B01_0119.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 87, 'High Damage (HD)': 3, 'Other': 11, 'Total tree': 101, 'Health Score': 0.0, 'Damaged or Stressed': 89.10891089108911, 'Label': 'Damaged/Stressed'}
# Counts for B01_0120.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 63, 'High Damage (HD)': 14, 'Other': 18, 'Total tree': 95, 'Health Score': 0.0, 'Damaged or Stressed': 81.05263157894737, 'Label': 'Damaged/Stressed'}
# Counts for B01_0121.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 23, 'High Damage (HD)': 20, 'Other': 36, 'Total tree': 79, 'Health Score': 0.0, 'Damaged or Stressed': 54.43037974683544, 'Label': 'Damaged/Stressed'}
# Counts for B01_0122.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 21, 'High Damage (HD)': 16, 'Other': 20, 'Total tree': 57, 'Health Score': 0.0, 'Damaged or Stressed': 64.91228070175438, 'Label': 'Damaged/Stressed'}
# Counts for B01_0123.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 28, 'High Damage (HD)': 9, 'Other': 17, 'Total tree': 54, 'Health Score': 0.0, 'Damaged or Stressed': 68.51851851851852, 'Label': 'Damaged/Stressed'}
# Counts for B01_0124.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 51, 'High Damage (HD)': 17, 'Other': 13, 'Total tree': 81, 'Health Score': 0.0, 'Damaged or Stressed': 83.9506172839506, 'Label': 'Damaged/Stressed'}
# Counts for B01_0125.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 60, 'High Damage (HD)': 6, 'Other': 13, 'Total tree': 79, 'Health Score': 0.0, 'Damaged or Stressed': 83.54430379746836, 'Label': 'Damaged/Stressed'}
# Counts for B01_0126.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 51, 'High Damage (HD)': 8, 'Other': 9, 'Total tree': 68, 'Health Score': 0.0, 'Damaged or Stressed': 86.76470588235294, 'Label': 'Damaged/Stressed'}
# Counts for B01_0127.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 42, 'High Damage (HD)': 8, 'Other': 9, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 84.7457627118644, 'Label': 'Damaged/Stressed'}
# Counts for B01_0128.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 54, 'High Damage (HD)': 0, 'Other': 3, 'Total tree': 57, 'Health Score': 0.0, 'Damaged or Stressed': 94.73684210526315, 'Label': 'Damaged/Stressed'}
# Counts for B01_0129.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 53, 'High Damage (HD)': 1, 'Other': 4, 'Total tree': 58, 'Health Score': 0.0, 'Damaged or Stressed': 93.10344827586206, 'Label': 'Damaged/Stressed'}
# Counts for B01_0130.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 36, 'High Damage (HD)': 5, 'Other': 6, 'Total tree': 47, 'Health Score': 0.0, 'Damaged or Stressed': 87.2340425531915, 'Label': 'Damaged/Stressed'}
# Counts for B01_0131.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 42, 'High Damage (HD)': 22, 'Other': 3, 'Total tree': 67, 'Health Score': 0.0, 'Damaged or Stressed': 95.52238805970148, 'Label': 'Damaged/Stressed'}
# Counts for B01_0132.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 68, 'High Damage (HD)': 9, 'Other': 0, 'Total tree': 77, 'Health Score': 0.0, 'Damaged or Stressed': 100.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0133.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 51, 'High Damage (HD)': 52, 'Other': 2, 'Total tree': 105, 'Health Score': 0.0, 'Damaged or Stressed': 98.09523809523809, 'Label': 'Damaged/Stressed'}
# Counts for B01_0134.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 21, 'High Damage (HD)': 57, 'Other': 7, 'Total tree': 85, 'Health Score': 0.0, 'Damaged or Stressed': 91.76470588235294, 'Label': 'Damaged/Stressed'}
# Counts for B01_0135.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 14, 'High Damage (HD)': 9, 'Other': 34, 'Total tree': 57, 'Health Score': 0.0, 'Damaged or Stressed': 40.35087719298245, 'Label': 'Damaged/Stressed'}
# Counts for B01_0136.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 3, 'High Damage (HD)': 3, 'Other': 45, 'Total tree': 51, 'Health Score': 0.0, 'Damaged or Stressed': 11.76470588235294, 'Label': 'Damaged/Stressed'}
# Counts for B01_0137.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 27, 'High Damage (HD)': 14, 'Other': 24, 'Total tree': 66, 'Health Score': 1.5151515151515151, 'Damaged or Stressed': 62.121212121212125, 'Label': 'Damaged/Stressed'}
# Counts for B01_0138.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 44, 'High Damage (HD)': 44, 'Other': 5, 'Total tree': 94, 'Health Score': 1.0638297872340425, 'Damaged or Stressed': 93.61702127659575, 'Label': 'Damaged/Stressed'}
# Counts for B01_0139.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 47, 'High Damage (HD)': 62, 'Other': 1, 'Total tree': 110, 'Health Score': 0.0, 'Damaged or Stressed': 99.0909090909091, 'Label': 'Damaged/Stressed'}
# Counts for B01_0140.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 43, 'High Damage (HD)': 63, 'Other': 6, 'Total tree': 112, 'Health Score': 0.0, 'Damaged or Stressed': 94.64285714285714, 'Label': 'Damaged/Stressed'}
# Counts for B01_0141.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 55, 'High Damage (HD)': 34, 'Other': 6, 'Total tree': 95, 'Health Score': 0.0, 'Damaged or Stressed': 93.6842105263158, 'Label': 'Damaged/Stressed'}
# Counts for B01_0142.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 53, 'High Damage (HD)': 20, 'Other': 3, 'Total tree': 78, 'Health Score': 2.564102564102564, 'Damaged or Stressed': 93.58974358974359, 'Label': 'Damaged/Stressed'}
# Counts for B01_0143.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 66, 'High Damage (HD)': 2, 'Other': 6, 'Total tree': 74, 'Health Score': 0.0, 'Damaged or Stressed': 91.8918918918919, 'Label': 'Damaged/Stressed'}
# Counts for B01_0144.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 68, 'High Damage (HD)': 3, 'Other': 7, 'Total tree': 78, 'Health Score': 0.0, 'Damaged or Stressed': 91.02564102564102, 'Label': 'Damaged/Stressed'}
# Counts for B01_0145.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 71, 'High Damage (HD)': 9, 'Other': 3, 'Total tree': 83, 'Health Score': 0.0, 'Damaged or Stressed': 96.3855421686747, 'Label': 'Damaged/Stressed'}
# Counts for B01_0146.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 61, 'High Damage (HD)': 9, 'Other': 20, 'Total tree': 91, 'Health Score': 1.098901098901099, 'Damaged or Stressed': 76.92307692307693, 'Label': 'Damaged/Stressed'}
# Counts for B01_0147.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 18, 'High Damage (HD)': 17, 'Other': 29, 'Total tree': 64, 'Health Score': 0.0, 'Damaged or Stressed': 54.6875, 'Label': 'Damaged/Stressed'}
# Counts for B01_0148.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 6, 'High Damage (HD)': 8, 'Other': 26, 'Total tree': 40, 'Health Score': 0.0, 'Damaged or Stressed': 35.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0149.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 5, 'High Damage (HD)': 5, 'Other': 56, 'Total tree': 66, 'Health Score': 0.0, 'Damaged or Stressed': 15.151515151515152, 'Label': 'Damaged/Stressed'}
# Counts for B01_0150.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 24, 'High Damage (HD)': 21, 'Other': 49, 'Total tree': 94, 'Health Score': 0.0, 'Damaged or Stressed': 47.87234042553192, 'Label': 'Damaged/Stressed'}
# Counts for B01_0151.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 59, 'High Damage (HD)': 25, 'Other': 17, 'Total tree': 101, 'Health Score': 0.0, 'Damaged or Stressed': 83.16831683168317, 'Label': 'Damaged/Stressed'}
# Counts for B01_0152.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 81, 'High Damage (HD)': 9, 'Other': 3, 'Total tree': 93, 'Health Score': 0.0, 'Damaged or Stressed': 96.7741935483871, 'Label': 'Damaged/Stressed'}
# Counts for B01_0153.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 43, 'High Damage (HD)': 44, 'Other': 5, 'Total tree': 92, 'Health Score': 0.0, 'Damaged or Stressed': 94.56521739130434, 'Label': 'Damaged/Stressed'}
# Counts for B01_0154.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 39, 'High Damage (HD)': 60, 'Other': 7, 'Total tree': 106, 'Health Score': 0.0, 'Damaged or Stressed': 93.39622641509435, 'Label': 'Damaged/Stressed'}
# Counts for B01_0155.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 45, 'High Damage (HD)': 67, 'Other': 7, 'Total tree': 119, 'Health Score': 0.0, 'Damaged or Stressed': 94.11764705882352, 'Label': 'Damaged/Stressed'}
# Counts for B01_0156.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 41, 'High Damage (HD)': 67, 'Other': 6, 'Total tree': 114, 'Health Score': 0.0, 'Damaged or Stressed': 94.73684210526315, 'Label': 'Damaged/Stressed'}
# Counts for B01_0157.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 32, 'High Damage (HD)': 60, 'Other': 10, 'Total tree': 102, 'Health Score': 0.0, 'Damaged or Stressed': 90.19607843137256, 'Label': 'Damaged/Stressed'}
# Counts for B01_0158.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 9, 'High Damage (HD)': 22, 'Other': 26, 'Total tree': 57, 'Health Score': 0.0, 'Damaged or Stressed': 54.385964912280706, 'Label': 'Damaged/Stressed'}
# Counts for B01_0159.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 7, 'High Damage (HD)': 16, 'Other': 35, 'Total tree': 58, 'Health Score': 0.0, 'Damaged or Stressed': 39.6551724137931, 'Label': 'Damaged/Stressed'}
# Counts for B01_0160.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 17, 'High Damage (HD)': 34, 'Other': 22, 'Total tree': 73, 'Health Score': 0.0, 'Damaged or Stressed': 69.86301369863014, 'Label': 'Damaged/Stressed'}
# Counts for B01_0161.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 56, 'High Damage (HD)': 27, 'Other': 19, 'Total tree': 102, 'Health Score': 0.0, 'Damaged or Stressed': 81.37254901960785, 'Label': 'Damaged/Stressed'}
# Counts for B01_0162.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 37, 'High Damage (HD)': 43, 'Other': 14, 'Total tree': 94, 'Health Score': 0.0, 'Damaged or Stressed': 85.1063829787234, 'Label': 'Damaged/Stressed'}
# Counts for B01_0163.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 31, 'High Damage (HD)': 49, 'Other': 7, 'Total tree': 87, 'Health Score': 0.0, 'Damaged or Stressed': 91.95402298850574, 'Label': 'Damaged/Stressed'}
# Counts for B01_0164.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 39, 'High Damage (HD)': 51, 'Other': 16, 'Total tree': 106, 'Health Score': 0.0, 'Damaged or Stressed': 84.90566037735849, 'Label': 'Damaged/Stressed'}
# Counts for B01_0165.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 34, 'High Damage (HD)': 59, 'Other': 14, 'Total tree': 107, 'Health Score': 0.0, 'Damaged or Stressed': 86.91588785046729, 'Label': 'Damaged/Stressed'}
# Counts for B01_0166.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 49, 'High Damage (HD)': 46, 'Other': 16, 'Total tree': 111, 'Health Score': 0.0, 'Damaged or Stressed': 85.58558558558559, 'Label': 'Damaged/Stressed'}
# Counts for B01_0167.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 58, 'High Damage (HD)': 8, 'Other': 41, 'Total tree': 107, 'Health Score': 0.0, 'Damaged or Stressed': 61.6822429906542, 'Label': 'Damaged/Stressed'}
# Counts for B01_0168.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 45, 'High Damage (HD)': 7, 'Other': 47, 'Total tree': 99, 'Health Score': 0.0, 'Damaged or Stressed': 52.52525252525253, 'Label': 'Damaged/Stressed'}
# Counts for B01_0169.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 34, 'High Damage (HD)': 5, 'Other': 54, 'Total tree': 93, 'Health Score': 0.0, 'Damaged or Stressed': 41.935483870967744, 'Label': 'Damaged/Stressed'}
# Counts for B01_0170.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 10, 'High Damage (HD)': 4, 'Other': 46, 'Total tree': 60, 'Health Score': 0.0, 'Damaged or Stressed': 23.333333333333332, 'Label': 'Damaged/Stressed'}
# Counts for B01_0171.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 5, 'High Damage (HD)': 1, 'Other': 34, 'Total tree': 40, 'Health Score': 0.0, 'Damaged or Stressed': 15.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0172.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 20, 'High Damage (HD)': 1, 'Other': 31, 'Total tree': 52, 'Health Score': 0.0, 'Damaged or Stressed': 40.38461538461539, 'Label': 'Damaged/Stressed'}
# Counts for B01_0173.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 25, 'High Damage (HD)': 1, 'Other': 25, 'Total tree': 51, 'Health Score': 0.0, 'Damaged or Stressed': 50.98039215686274, 'Label': 'Damaged/Stressed'}
# Counts for B01_0174.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 18, 'High Damage (HD)': 2, 'Other': 22, 'Total tree': 42, 'Health Score': 0.0, 'Damaged or Stressed': 47.61904761904761, 'Label': 'Damaged/Stressed'}
# Counts for B01_0175.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 12, 'High Damage (HD)': 12, 'Other': 21, 'Total tree': 45, 'Health Score': 0.0, 'Damaged or Stressed': 53.333333333333336, 'Label': 'Damaged/Stressed'}
# Counts for B01_0176.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 3, 'High Damage (HD)': 20, 'Other': 23, 'Total tree': 46, 'Health Score': 0.0, 'Damaged or Stressed': 50.0, 'Label': 'Damaged/Stressed'}
# Counts for B01_0177.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 6, 'High Damage (HD)': 39, 'Other': 24, 'Total tree': 69, 'Health Score': 0.0, 'Damaged or Stressed': 65.21739130434783, 'Label': 'Damaged/Stressed'}
# Counts for B01_0178.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 20, 'High Damage (HD)': 73, 'Other': 17, 'Total tree': 110, 'Health Score': 0.0, 'Damaged or Stressed': 84.54545454545455, 'Label': 'Damaged/Stressed'}
# Counts for B01_0179.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 31, 'High Damage (HD)': 71, 'Other': 12, 'Total tree': 114, 'Health Score': 0.0, 'Damaged or Stressed': 89.47368421052632, 'Label': 'Damaged/Stressed'}
# Counts for B01_0180.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 57, 'High Damage (HD)': 14, 'Other': 28, 'Total tree': 99, 'Health Score': 0.0, 'Damaged or Stressed': 71.71717171717171, 'Label': 'Damaged/Stressed'}
# Counts for B02_0003.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 11, 'High Damage (HD)': 0, 'Other': 5, 'Total tree': 16, 'Health Score': 0.0, 'Damaged or Stressed': 68.75, 'Label': 'Damaged/Stressed'}
# Counts for B02_0004.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 30, 'High Damage (HD)': 3, 'Other': 5, 'Total tree': 38, 'Health Score': 0.0, 'Damaged or Stressed': 86.8421052631579, 'Label': 'Damaged/Stressed'}
# Counts for B02_0005.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 37, 'High Damage (HD)': 6, 'Other': 7, 'Total tree': 50, 'Health Score': 0.0, 'Damaged or Stressed': 86.0, 'Label': 'Damaged/Stressed'}
# Counts for B02_0006.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 25, 'High Damage (HD)': 2, 'Other': 16, 'Total tree': 43, 'Health Score': 0.0, 'Damaged or Stressed': 62.7906976744186, 'Label': 'Damaged/Stressed'}
# Counts for B02_0007.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 9, 'High Damage (HD)': 1, 'Other': 35, 'Total tree': 45, 'Health Score': 0.0, 'Damaged or Stressed': 22.22222222222222, 'Label': 'Damaged/Stressed'}
# Counts for B02_0008.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 8, 'High Damage (HD)': 0, 'Other': 43, 'Total tree': 51, 'Health Score': 0.0, 'Damaged or Stressed': 15.686274509803921, 'Label': 'Damaged/Stressed'}
# Counts for B02_0009.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 1, 'High Damage (HD)': 0, 'Other': 46, 'Total tree': 47, 'Health Score': 0.0, 'Damaged or Stressed': 2.127659574468085, 'Label': 'Damaged/Stressed'}
# Counts for B02_0012.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 14, 'High Damage (HD)': 2, 'Other': 51, 'Total tree': 67, 'Health Score': 0.0, 'Damaged or Stressed': 23.88059701492537, 'Label': 'Damaged/Stressed'}
# Counts for B02_0013.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 61, 'High Damage (HD)': 2, 'Other': 12, 'Total tree': 75, 'Health Score': 0.0, 'Damaged or Stressed': 84.0, 'Label': 'Damaged/Stressed'}
# Counts for B02_0014.JPG: {'Healthy (H)': 8, 'Light Damage (LD)': 58, 'High Damage (HD)': 0, 'Other': 0, 'Total tree': 66, 'Health Score': 12.121212121212121, 'Damaged or Stressed': 87.87878787878788, 'Label': 'Damaged/Stressed'}
# Counts for B02_0015.JPG: {'Healthy (H)': 14, 'Light Damage (LD)': 45, 'High Damage (HD)': 0, 'Other': 0, 'Total tree': 59, 'Health Score': 23.728813559322035, 'Damaged or Stressed': 76.27118644067797, 'Label': 'Damaged/Stressed'}
# Counts for B02_0016.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 60, 'High Damage (HD)': 1, 'Other': 1, 'Total tree': 63, 'Health Score': 1.5873015873015872, 'Damaged or Stressed': 96.82539682539682, 'Label': 'Damaged/Stressed'}
# Counts for B02_0017.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 50, 'High Damage (HD)': 1, 'Other': 1, 'Total tree': 52, 'Health Score': 0.0, 'Damaged or Stressed': 98.07692307692307, 'Label': 'Damaged/Stressed'}
# Counts for B02_0018.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 17, 'High Damage (HD)': 0, 'Other': 23, 'Total tree': 40, 'Health Score': 0.0, 'Damaged or Stressed': 42.5, 'Label': 'Damaged/Stressed'}
# Counts for B02_0019.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 10, 'High Damage (HD)': 0, 'Other': 34, 'Total tree': 44, 'Health Score': 0.0, 'Damaged or Stressed': 22.727272727272727, 'Label': 'Damaged/Stressed'}
# Counts for B02_0020.JPG: {'Healthy (H)': 5, 'Light Damage (LD)': 8, 'High Damage (HD)': 0, 'Other': 17, 'Total tree': 30, 'Health Score': 16.666666666666664, 'Damaged or Stressed': 26.666666666666668, 'Label': 'Damaged/Stressed'}
# Counts for B02_0021.JPG: {'Healthy (H)': 11, 'Light Damage (LD)': 31, 'High Damage (HD)': 0, 'Other': 2, 'Total tree': 44, 'Health Score': 25.0, 'Damaged or Stressed': 70.45454545454545, 'Label': 'Damaged/Stressed'}
# Counts for B02_0022.JPG: {'Healthy (H)': 9, 'Light Damage (LD)': 52, 'High Damage (HD)': 0, 'Other': 0, 'Total tree': 61, 'Health Score': 14.754098360655737, 'Damaged or Stressed': 85.24590163934425, 'Label': 'Damaged/Stressed'}
# Counts for B02_0023.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 54, 'High Damage (HD)': 0, 'Other': 0, 'Total tree': 55, 'Health Score': 1.8181818181818181, 'Damaged or Stressed': 98.18181818181819, 'Label': 'Damaged/Stressed'}
# Counts for B02_0024.JPG: {'Healthy (H)': 6, 'Light Damage (LD)': 44, 'High Damage (HD)': 0, 'Other': 1, 'Total tree': 51, 'Health Score': 11.76470588235294, 'Damaged or Stressed': 86.27450980392157, 'Label': 'Damaged/Stressed'}
# Counts for B02_0025.JPG: {'Healthy (H)': 3, 'Light Damage (LD)': 47, 'High Damage (HD)': 1, 'Other': 1, 'Total tree': 52, 'Health Score': 5.769230769230769, 'Damaged or Stressed': 92.3076923076923, 'Label': 'Damaged/Stressed'}
# Counts for B02_0026.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 59, 'High Damage (HD)': 0, 'Other': 2, 'Total tree': 63, 'Health Score': 3.1746031746031744, 'Damaged or Stressed': 93.65079365079364, 'Label': 'Damaged/Stressed'}
# Counts for B02_0027.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 29, 'High Damage (HD)': 4, 'Other': 33, 'Total tree': 66, 'Health Score': 0.0, 'Damaged or Stressed': 50.0, 'Label': 'Damaged/Stressed'}
# Counts for B02_0038.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 14, 'High Damage (HD)': 3, 'Other': 57, 'Total tree': 74, 'Health Score': 0.0, 'Damaged or Stressed': 22.972972972972975, 'Label': 'Damaged/Stressed'}
# Counts for B02_0039.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 48, 'High Damage (HD)': 2, 'Other': 14, 'Total tree': 64, 'Health Score': 0.0, 'Damaged or Stressed': 78.125, 'Label': 'Damaged/Stressed'}
# Counts for B02_0040.JPG: {'Healthy (H)': 11, 'Light Damage (LD)': 40, 'High Damage (HD)': 1, 'Other': 6, 'Total tree': 58, 'Health Score': 18.96551724137931, 'Damaged or Stressed': 70.6896551724138, 'Label': 'Damaged/Stressed'}
# Counts for B02_0041.JPG: {'Healthy (H)': 5, 'Light Damage (LD)': 38, 'High Damage (HD)': 0, 'Other': 11, 'Total tree': 54, 'Health Score': 9.25925925925926, 'Damaged or Stressed': 70.37037037037037, 'Label': 'Damaged/Stressed'}
# Counts for B02_0042.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 49, 'High Damage (HD)': 1, 'Other': 5, 'Total tree': 55, 'Health Score': 0.0, 'Damaged or Stressed': 90.9090909090909, 'Label': 'Damaged/Stressed'}
# Counts for B02_0043.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 50, 'High Damage (HD)': 7, 'Other': 2, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 96.61016949152543, 'Label': 'Damaged/Stressed'}
# Counts for B02_0044.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 50, 'High Damage (HD)': 5, 'Other': 5, 'Total tree': 60, 'Health Score': 0.0, 'Damaged or Stressed': 91.66666666666666, 'Label': 'Damaged/Stressed'}
# Counts for B02_0045.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 47, 'High Damage (HD)': 3, 'Other': 7, 'Total tree': 57, 'Health Score': 0.0, 'Damaged or Stressed': 87.71929824561403, 'Label': 'Damaged/Stressed'}
# Counts for B02_0046.JPG: {'Healthy (H)': 7, 'Light Damage (LD)': 41, 'High Damage (HD)': 1, 'Other': 3, 'Total tree': 52, 'Health Score': 13.461538461538462, 'Damaged or Stressed': 80.76923076923077, 'Label': 'Damaged/Stressed'}
# Counts for B02_0047.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 35, 'High Damage (HD)': 2, 'Other': 2, 'Total tree': 39, 'Health Score': 0.0, 'Damaged or Stressed': 94.87179487179486, 'Label': 'Damaged/Stressed'}
# Counts for B02_0048.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 14, 'High Damage (HD)': 0, 'Other': 17, 'Total tree': 31, 'Health Score': 0.0, 'Damaged or Stressed': 45.16129032258064, 'Label': 'Damaged/Stressed'}
# Counts for B02_0049.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 9, 'High Damage (HD)': 0, 'Other': 32, 'Total tree': 41, 'Health Score': 0.0, 'Damaged or Stressed': 21.951219512195124, 'Label': 'Damaged/Stressed'}
# Counts for B02_0050.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 9, 'High Damage (HD)': 0, 'Other': 27, 'Total tree': 36, 'Health Score': 0.0, 'Damaged or Stressed': 25.0, 'Label': 'Damaged/Stressed'}
# Counts for B02_0051.JPG: {'Healthy (H)': 9, 'Light Damage (LD)': 4, 'High Damage (HD)': 0, 'Other': 13, 'Total tree': 26, 'Health Score': 34.61538461538461, 'Damaged or Stressed': 15.384615384615385, 'Label': 'Damaged/Stressed'}
# Counts for B02_0052.JPG: {'Healthy (H)': 7, 'Light Damage (LD)': 25, 'High Damage (HD)': 0, 'Other': 2, 'Total tree': 34, 'Health Score': 20.588235294117645, 'Damaged or Stressed': 73.52941176470588, 'Label': 'Damaged/Stressed'}
# Counts for B02_0053.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 36, 'High Damage (HD)': 1, 'Other': 4, 'Total tree': 42, 'Health Score': 2.380952380952381, 'Damaged or Stressed': 88.09523809523809, 'Label': 'Damaged/Stressed'}
# Counts for B02_0054.JPG: {'Healthy (H)': 2, 'Light Damage (LD)': 46, 'High Damage (HD)': 1, 'Other': 5, 'Total tree': 54, 'Health Score': 3.7037037037037033, 'Damaged or Stressed': 87.03703703703704, 'Label': 'Damaged/Stressed'}
# Counts for B02_0055.JPG: {'Healthy (H)': 12, 'Light Damage (LD)': 44, 'High Damage (HD)': 1, 'Other': 0, 'Total tree': 57, 'Health Score': 21.052631578947366, 'Damaged or Stressed': 78.94736842105263, 'Label': 'Damaged/Stressed'}
# Counts for B02_0056.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 55, 'High Damage (HD)': 4, 'Other': 1, 'Total tree': 61, 'Health Score': 1.639344262295082, 'Damaged or Stressed': 96.72131147540983, 'Label': 'Damaged/Stressed'}
# Counts for B02_0057.JPG: {'Healthy (H)': 1, 'Light Damage (LD)': 46, 'High Damage (HD)': 10, 'Other': 9, 'Total tree': 66, 'Health Score': 1.5151515151515151, 'Damaged or Stressed': 84.84848484848484, 'Label': 'Damaged/Stressed'}
# Counts for B02_0058.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 32, 'High Damage (HD)': 21, 'Other': 13, 'Total tree': 66, 'Health Score': 0.0, 'Damaged or Stressed': 80.3030303030303, 'Label': 'Damaged/Stressed'}
# Counts for B02_0059.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 33, 'High Damage (HD)': 10, 'Other': 21, 'Total tree': 64, 'Health Score': 0.0, 'Damaged or Stressed': 67.1875, 'Label': 'Damaged/Stressed'}
# Counts for B02_0060.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 27, 'High Damage (HD)': 18, 'Other': 9, 'Total tree': 54, 'Health Score': 0.0, 'Damaged or Stressed': 83.33333333333334, 'Label': 'Damaged/Stressed'}
# Counts for B02_0061.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 41, 'High Damage (HD)': 8, 'Other': 6, 'Total tree': 55, 'Health Score': 0.0, 'Damaged or Stressed': 89.0909090909091, 'Label': 'Damaged/Stressed'}
# Counts for B02_0062.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 31, 'High Damage (HD)': 11, 'Other': 7, 'Total tree': 49, 'Health Score': 0.0, 'Damaged or Stressed': 85.71428571428571, 'Label': 'Damaged/Stressed'}
# Counts for B02_0063.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 19, 'High Damage (HD)': 22, 'Other': 3, 'Total tree': 44, 'Health Score': 0.0, 'Damaged or Stressed': 93.18181818181817, 'Label': 'Damaged/Stressed'}
# ...
# Counts for B10_0143.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 59, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0144.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 66, 'Total tree': 66, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0145.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 76, 'Total tree': 76, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0146.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 67, 'Total tree': 67, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0147.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 59, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0148.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 52, 'Total tree': 52, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0149.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 46, 'Total tree': 46, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0150.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 41, 'Total tree': 41, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0151.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 63, 'Total tree': 63, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0152.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 52, 'Total tree': 52, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0153.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 56, 'Total tree': 56, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0154.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 63, 'Total tree': 63, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0155.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 72, 'Total tree': 72, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0156.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 75, 'Total tree': 75, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0157.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 64, 'Total tree': 64, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0158.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 31, 'Total tree': 31, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0159.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 21, 'Total tree': 21, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0160.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 20, 'Total tree': 20, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0161.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 29, 'Total tree': 29, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0162.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 56, 'Total tree': 56, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0163.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 74, 'Total tree': 74, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0164.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 78, 'Total tree': 78, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0165.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 58, 'Total tree': 58, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0166.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 49, 'Total tree': 49, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0167.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 47, 'Total tree': 47, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0168.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 49, 'Total tree': 49, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0169.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 52, 'Total tree': 52, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0170.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 49, 'Total tree': 49, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0171.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 59, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0172.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 70, 'Total tree': 70, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0173.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 70, 'Total tree': 70, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0174.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 68, 'Total tree': 68, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0175.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 65, 'Total tree': 65, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0176.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 52, 'Total tree': 52, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0177.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 52, 'Total tree': 52, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0178.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 24, 'Total tree': 24, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0179.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 15, 'Total tree': 15, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0180.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 20, 'Total tree': 20, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0181.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 12, 'Total tree': 12, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0182.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 19, 'Total tree': 19, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0183.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 48, 'Total tree': 48, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0184.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 59, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0185.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 73, 'Total tree': 73, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0186.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 73, 'Total tree': 73, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0187.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 71, 'Total tree': 71, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0188.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 73, 'Total tree': 73, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0189.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 43, 'Total tree': 43, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0190.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 48, 'Total tree': 48, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0191.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 40, 'Total tree': 40, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0192.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 42, 'Total tree': 42, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0193.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 45, 'Total tree': 45, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0194.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 58, 'Total tree': 58, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0195.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 67, 'Total tree': 67, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0196.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 68, 'Total tree': 68, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0197.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 71, 'Total tree': 71, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0198.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 78, 'Total tree': 78, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0199.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 70, 'Total tree': 70, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0200.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 74, 'Total tree': 74, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0201.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 59, 'Total tree': 59, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0202.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 44, 'Total tree': 44, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0203.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 27, 'Total tree': 27, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0204.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 29, 'Total tree': 29, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0205.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 28, 'Total tree': 28, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0206.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 27, 'Total tree': 27, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0207.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 21, 'Total tree': 21, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0208.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 23, 'Total tree': 23, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0209.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 22, 'Total tree': 22, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0210.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 35, 'Total tree': 35, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0211.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 51, 'Total tree': 51, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0212.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 43, 'Total tree': 43, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0213.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 23, 'Total tree': 23, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0214.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 19, 'Total tree': 19, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0215.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 18, 'Total tree': 18, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0216.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 11, 'Total tree': 11, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0217.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 17, 'Total tree': 17, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0218.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 19, 'Total tree': 19, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0219.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 16, 'Total tree': 16, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0220.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 21, 'Total tree': 21, 'Health Score': 0.0, 'Damaged or Stressed': 0.0, 'Label': 'Damaged/Stressed'}
# Counts for B10_0221.JPG: {'Healthy (H)': 0, 'Light Damage (LD)': 0, 'High Damage (HD)': 0, 'Other': 0, 'Total tree': 0, 'Health Score': 0, 'Damaged or Stressed': 0, 'Label': 'Damaged/Stressed'}
# Total counts across the dataset:
# Healthy (H): 2638
# Light Damage (LD): 33298
# High Damage (HD): 9084
# Other: 56814

# %%
# !pip install timm
# Out:
# Collecting timm
#   Using cached timm-1.0.11-py3-none-any.whl (2.3 MB)
# Requirement already satisfied: torchvision in c:\users\user\anaconda3\lib\site-packages (from timm) (0.19.0)
# Requirement already satisfied: safetensors in c:\users\user\anaconda3\lib\site-packages (from timm) (0.4.5)
# Collecting huggingface_hub
#   Using cached huggingface_hub-0.26.0-py3-none-any.whl (447 kB)
# Requirement already satisfied: torch in c:\users\user\anaconda3\lib\site-packages (from timm) (2.4.0)
# Requirement already satisfied: pyyaml in c:\users\user\anaconda3\lib\site-packages (from timm) (6.0)
# Collecting fsspec>=2023.5.0
#   Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\user\anaconda3\lib\site-packages (from huggingface_hub->timm) (4.64.1)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from huggingface_hub->timm) (2.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\user\anaconda3\lib\site-packages (from huggingface_hub->timm) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\anaconda3\lib\site-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from huggingface_hub->timm) (3.6.0)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch->timm) (2.11.3)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from torch->timm) (1.10.1)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch->timm) (2.8.4)
# Requirement already satisfied: numpy<2 in c:\users\user\anaconda3\lib\site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\user\anaconda3\lib\site-packages (from torchvision->timm) (9.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=20.9->huggingface_hub->timm) (3.0.9)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->timm) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch->timm) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2.0.4)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->torch->timm) (1.2.1)
# Installing collected packages: fsspec, huggingface_hub, timm
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.7.1
#     Uninstalling fsspec-2022.7.1:
#       Successfully uninstalled fsspec-2022.7.1
# Successfully installed fsspec-2024.9.0 huggingface_hub-0.26.0 timm-1.0.11

# %%
import timm

# %%
import torch
import torch.nn as nn
model = timm.create_model('swin_base_patch4_window7_224', pretrained=True)

# Modify the final classification layer to match the number of health categories (e.g., 4)
num_classes = 4  # Assuming 4 classes: Healthy, Light Damage, High Damage, Other
model.head = nn.Linear(model.head.in_features, num_classes)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
import numpy as np
import xml.etree.ElementTree as ET

def create_segmentation_mask(annotation_file, image_size):
    mask = np.zeros(image_size, dtype=np.uint8)  # Initialize mask with zeros (default: 'Other')
    
    tree = ET.parse(annotation_file)
    root = tree.getroot()
    
    for obj in root.iter('object'):
        bndbox = obj.find('bndbox')
        xmin = int(bndbox.find('xmin').text)
        ymin = int(bndbox.find('ymin').text)
        xmax = int(bndbox.find('xmax').text)
        ymax = int(bndbox.find('ymax').text)

        # Get damage type from annotation
        damage_status = obj.find('damage').text
        
        # Map the damage status to a number (you can modify this mapping)
        if damage_status == 'H':
            label = 0  # Healthy
        elif damage_status == 'LD':
            label = 1  # Light Damage
        elif damage_status == 'HD':
            label = 2  # High Damage
        else:
            label = 3  # Other

        # Fill the bounding box area in the mask with the label
        mask[ymin:ymax, xmin:xmax] = label
    
    return mask

# %%
from torch.utils.data import Dataset

class ForestSegmentationDataset(Dataset):
    def __init__(self, image_dir, annotation_dir, transform=None):
        self.image_dir = image_dir
        self.annotation_dir = annotation_dir
        self.transform = transform
        self.image_filenames = os.listdir(image_dir)
    
    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        img_name = self.image_filenames[idx]
        img_path = os.path.join(self.image_dir, img_name)
        annotation_file = os.path.join(self.annotation_dir, img_name.replace('.JPG', '.xml'))
        
        # Load image
        image = Image.open(img_path).convert('RGB')
        
        # Create segmentation mask
        mask = create_segmentation_mask(annotation_file, image.size)

        # Apply transforms
        if self.transform:
            image = self.transform(image)
            mask = torch.tensor(mask, dtype=torch.long)  # Convert mask to tensor

        return image, mask

# %%
import torchvision.models.segmentation as models

# Load the segmentation model with a pre-trained Swin Transformer backbone
model = models.deeplabv3_resnet50(pretrained=True)  # You can also use Swin backbone

# Modify the classifier to output 4 classes (Healthy, Light Damage, High Damage, Other)
model.classifier[4] = nn.Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))

# Move to GPU if available
model = model.to(device)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DeepLabV3_ResNet50_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=DeepLabV3_ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet50_coco-cd0a2569.pth" to C:\Users\User/.cache\torch\hub\checkpoints\deeplabv3_resnet50_coco-cd0a2569.pth
# 100%|███████████████████████████████████████████████████████████████████████████████| 161M/161M [00:46<00:00, 3.60MB/s]

# %%
# Loss function for segmentation (CrossEntropyLoss works well for multi-class segmentation)
criterion = nn.CrossEntropyLoss()

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs=15
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    
    for images, masks in train_loader:
        images = images.to(device)
        masks = masks.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(images)['out']  # DeepLabV3 returns a dict, so we get 'out'
        loss = criterion(outputs, masks)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(train_loader):.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41332\3314784875.py in <module>
#      11     running_loss = 0.0
#      12
# ---> 13     for images, masks in train_loader:
#      14         images = images.to(device)
#      15         masks = masks.to(device)
#
# NameError: name 'train_loader' is not defined

# %%
def calculate_health_metrics(predicted_mask):
    # Count the number of pixels for each class
    total_pixels = predicted_mask.size
    healthy_pixels = (predicted_mask == 0).sum()
    light_damage_pixels = (predicted_mask == 1).sum()
    high_damage_pixels = (predicted_mask == 2).sum()
    other_pixels = (predicted_mask == 3).sum()

    # Calculate percentages
    healthy_percentage = (healthy_pixels / total_pixels) * 100
    light_damage_percentage = (light_damage_pixels / total_pixels) * 100
    high_damage_percentage = (high_damage_pixels / total_pixels) * 100
    other_percentage = (other_pixels / total_pixels) * 100

    return {
        'Healthy %': healthy_percentage,
        'Light Damage %': light_damage_percentage,
        'High Damage %': high_damage_percentage,
        'Other %': other_percentage
    }

# Example usage
predicted_mask = model(image)['out'].argmax(1)  # Get the predicted class for each pixel
metrics = calculate_health_metrics(predicted_mask)
print(metrics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41332\54169909.py in <module>
#      21
#      22 # Example usage
# ---> 23 predicted_mask = model(image)['out'].argmax(1)  # Get the predicted class for each pixel
#      24 metrics = calculate_health_metrics(predicted_mask)
#      25 print(metrics)
#
# NameError: name 'image' is not defined
